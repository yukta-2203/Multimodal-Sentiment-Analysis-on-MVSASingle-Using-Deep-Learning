# %%
# !pip install -q torch torchvision transformers pillow pandas scikit-learn

# %%
ZIP_PATH = "/content/mvsa.zip"   # change if filename is different

# !mkdir -p /content/mvsa_raw
# !unzip -o "$ZIP_PATH" -d /content/mvsa_raw

# !ls -R /content/mvsa_raw
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/mvsa_raw/MVSA_Single/data/3916.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3916.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3917.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3917.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3918.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3918.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3919.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3919.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/392.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/392.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3920.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3920.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3921.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3921.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3922.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3922.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3923.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3923.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3924.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3924.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3925.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3925.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3926.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3926.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3927.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3927.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3928.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3928.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3929.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3929.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/393.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/393.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3930.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3930.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3931.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3931.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3932.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3932.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3933.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3933.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3934.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3934.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3935.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3935.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3936.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3936.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3937.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3937.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3938.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3938.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3939.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3939.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/394.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/394.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3940.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3940.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3941.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3941.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3942.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3942.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3943.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3943.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3944.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3944.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3945.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3945.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3946.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3946.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3947.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3947.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3948.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3948.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3949.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3949.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/395.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/395.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3950.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3950.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3951.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3951.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3952.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3952.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3953.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3953.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3954.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3954.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3955.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3955.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3956.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3956.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3957.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3957.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3958.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3958.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3959.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3959.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/396.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/396.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3961.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3961.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3962.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3962.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3963.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3963.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3964.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3964.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3965.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3965.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3966.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3966.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3967.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3967.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3968.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3968.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3969.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3969.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/397.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/397.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3970.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3970.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3971.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3971.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3972.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3972.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3973.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3973.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3974.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3974.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3975.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3975.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3976.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3976.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3977.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3977.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3978.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3978.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3979.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3979.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/398.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/398.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3980.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3980.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3981.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3981.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3982.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3982.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3983.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3983.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3984.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3984.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3985.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3985.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3986.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3986.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3987.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3987.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3988.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3988.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3989.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3989.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/399.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/399.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3990.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3990.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3991.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3991.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3992.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3992.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3993.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3993.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3994.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3994.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3995.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3995.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3996.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3996.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3997.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3997.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3998.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3998.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/3999.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/3999.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/40.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/40.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/400.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/400.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4000.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4000.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4001.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4001.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4002.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4002.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4003.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4003.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4004.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4004.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4005.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4005.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4006.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4006.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4007.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4007.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4008.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4008.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4009.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4009.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/401.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/401.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4010.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4010.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4011.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4011.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4012.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4012.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4013.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4013.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4014.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4014.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4015.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4015.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4016.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4016.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4017.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4017.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4018.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4018.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4019.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4019.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/402.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/402.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4020.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4020.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4021.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4021.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4022.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4022.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4023.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4023.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4024.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4024.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4025.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4025.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4026.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4026.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4027.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4027.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4028.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4028.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4029.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4029.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/403.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/403.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4030.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4030.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4031.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4031.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4032.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4032.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4033.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4033.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4034.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4034.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4035.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4035.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4036.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4036.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4037.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4037.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4038.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4038.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4039.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4039.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/404.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/404.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4040.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4040.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4041.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4041.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4042.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4042.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4043.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4043.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4044.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4044.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4045.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4045.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4046.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4046.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4047.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4047.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4048.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4048.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4049.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4049.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/405.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/405.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4050.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4050.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4051.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4051.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4052.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4052.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4053.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4053.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4054.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4054.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4055.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4055.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4056.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4056.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4057.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4057.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4058.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4058.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4059.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4059.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/406.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/406.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4060.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4060.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4061.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4061.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4062.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4062.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4063.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4063.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4064.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4064.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4065.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4065.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4066.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4066.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4067.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4067.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4068.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4068.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4069.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4069.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/407.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/407.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4070.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4070.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4071.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4071.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4072.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4072.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4073.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4073.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4074.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4074.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4075.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4075.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4076.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4076.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4077.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4077.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4078.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4078.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4079.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4079.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/408.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/408.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4080.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4080.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4081.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4081.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4082.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4082.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4083.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4083.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4084.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4084.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4085.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4085.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4086.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4086.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4087.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4087.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4088.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4088.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4089.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4089.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/409.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/409.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4090.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4090.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4091.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4091.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4092.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4092.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4093.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4093.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4094.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4094.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4095.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4095.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4096.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4096.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4097.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4097.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4098.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4098.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4099.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4099.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/41.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/41.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/410.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/410.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4100.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4100.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4101.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4101.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4102.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4102.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4103.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4103.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4104.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4104.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4105.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4105.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4106.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4106.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4107.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4107.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4108.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4108.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4109.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4109.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/411.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/411.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4110.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4110.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4111.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4111.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4112.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4112.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4113.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4113.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4114.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4114.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4115.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4115.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4116.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4116.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4117.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4117.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4118.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4118.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4119.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4119.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/412.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/412.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4120.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4120.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4121.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4121.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4122.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4122.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4123.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4123.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4124.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4124.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4125.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4125.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4126.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4126.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4127.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4127.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4128.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4128.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4129.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4129.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/413.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/413.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4130.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4130.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4131.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4131.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4132.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4132.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4133.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4133.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4134.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4134.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4135.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4135.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4136.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4136.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4137.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4137.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4138.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4138.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4139.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4139.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/414.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/414.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4140.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4140.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4141.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4141.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4142.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4142.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4143.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4143.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4144.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4144.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4145.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4145.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4146.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4146.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4147.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4147.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4148.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4148.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4149.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4149.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/415.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/415.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4150.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4150.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4151.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4151.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4152.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4152.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4153.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4153.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4154.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4154.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4155.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4155.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4156.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4156.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4157.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4157.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4158.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4158.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4159.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4159.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/416.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/416.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4160.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4160.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4161.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4161.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4162.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4162.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4163.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4163.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4164.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4164.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4165.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4165.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4166.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4166.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4167.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4167.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4168.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4168.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4169.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4169.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/417.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/417.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4170.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4170.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4171.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4171.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4172.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4172.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4173.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4173.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4174.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4174.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4175.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4175.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4176.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4176.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4177.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4177.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4178.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4178.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4179.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4179.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/418.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/418.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4180.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4180.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4181.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4181.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4182.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4182.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4183.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4183.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4184.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4184.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4185.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4185.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4186.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4186.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4187.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4187.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4188.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4188.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4189.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4189.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/419.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/419.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4190.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4190.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4191.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4191.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4192.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4192.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4193.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4193.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4194.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4194.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4195.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4195.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4196.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4196.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4197.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4197.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4198.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4198.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4199.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4199.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/42.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/42.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/420.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/420.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4200.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4200.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4201.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4201.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4202.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4202.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4203.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4203.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4204.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4204.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4205.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4205.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4206.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4206.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4207.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4207.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4208.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4208.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4209.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4209.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/421.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/421.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4210.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4210.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4211.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4211.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4212.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4212.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4213.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4213.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4214.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4214.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4215.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4215.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4216.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4216.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4217.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4217.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4218.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4218.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4219.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4219.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/422.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/422.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4220.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4220.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4221.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4221.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4222.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4222.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4223.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4223.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4224.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4224.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4225.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4225.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4226.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4226.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4227.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4227.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4228.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4228.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4229.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4229.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/423.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/423.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4230.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4230.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4231.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4231.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4232.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4232.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4233.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4233.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4234.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4234.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4235.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4235.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4236.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4236.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4237.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4237.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4238.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4238.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4239.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4239.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/424.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/424.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4240.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4240.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4241.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4241.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4242.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4242.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4243.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4243.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4244.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4244.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4245.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4245.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4246.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4246.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4247.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4247.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4248.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4248.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4249.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4249.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/425.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/425.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4250.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4250.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4251.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4251.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4252.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4252.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4253.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4253.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4254.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4254.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4255.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4255.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4256.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4256.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4257.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4257.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4258.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4258.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4259.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4259.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/426.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/426.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4260.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4260.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4261.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4261.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4262.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4262.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4263.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4263.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4264.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4264.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4265.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4265.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4266.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4266.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4267.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4267.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4268.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4268.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4269.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4269.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/427.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/427.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4270.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4270.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4271.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4271.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4272.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4272.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4273.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4273.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4274.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4274.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4275.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4275.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4276.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4276.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4277.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4277.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4278.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4278.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4279.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4279.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/428.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/428.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4280.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4280.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4281.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4281.txt
#   inflating: /content/mvsa_raw/MVSA_Single/data/4282.jpg
#   inflating: /content/mvsa_raw/MVSA_Single/data/4282.txt
# ...
# 1455.txt  2002.txt  2745.txt  3315.txt	3879.txt  442.txt   4979.txt  909.txt
# 1456.jpg  2003.jpg  2746.jpg  3316.jpg	387.jpg   4430.jpg  497.jpg   90.jpg
# 1456.txt  2003.txt  2746.txt  3316.txt	387.txt   4430.txt  497.txt   90.txt
# 1457.jpg  2004.jpg  2747.jpg  3317.jpg	3880.jpg  4431.jpg  4980.jpg  910.jpg
# 1457.txt  2004.txt  2747.txt  3317.txt	3880.txt  4431.txt  4980.txt  910.txt
# 1458.jpg  2005.jpg  2748.jpg  3318.jpg	3881.jpg  4432.jpg  4981.jpg  911.jpg
# 1458.txt  2005.txt  2748.txt  3318.txt	3881.txt  4432.txt  4981.txt  911.txt
# 1459.jpg  2006.jpg  2749.jpg  3319.jpg	3882.jpg  4433.jpg  4982.jpg  912.jpg
# 1459.txt  2006.txt  2749.txt  3319.txt	3882.txt  4433.txt  4982.txt  912.txt
# 145.jpg   2007.jpg  274.jpg   331.jpg	3883.jpg  4434.jpg  4983.jpg  913.jpg
# 145.txt   2007.txt  274.txt   331.txt	3883.txt  4434.txt  4983.txt  913.txt
# 1460.jpg  2008.jpg  2750.jpg  3320.jpg	3884.jpg  4435.jpg  4984.jpg  914.jpg
# 1460.txt  2008.txt  2750.txt  3320.txt	3884.txt  4435.txt  4984.txt  914.txt
# 1461.jpg  2009.jpg  2751.jpg  3321.jpg	3885.jpg  4436.jpg  4985.jpg  915.jpg
# 1461.txt  2009.txt  2751.txt  3321.txt	3885.txt  4436.txt  4985.txt  915.txt
# 1462.jpg  200.jpg   2752.jpg  3322.jpg	3886.jpg  4437.jpg  4986.jpg  916.jpg
# 1462.txt  200.txt   2752.txt  3322.txt	3886.txt  4437.txt  4986.txt  916.txt
# 1463.jpg  2010.jpg  2753.jpg  3323.jpg	3887.jpg  4438.jpg  4987.jpg  917.jpg
# 1463.txt  2010.txt  2753.txt  3323.txt	3887.txt  4438.txt  4987.txt  917.txt
# 1464.jpg  2011.jpg  2754.jpg  3324.jpg	3888.jpg  4439.jpg  4988.jpg  918.jpg
# 1464.txt  2011.txt  2754.txt  3324.txt	3888.txt  4439.txt  4988.txt  918.txt
# 1465.jpg  2012.jpg  2755.jpg  3325.jpg	3889.jpg  443.jpg   4989.jpg  919.jpg
# 1465.txt  2012.txt  2755.txt  3325.txt	3889.txt  443.txt   4989.txt  919.txt
# 1466.jpg  2013.jpg  2757.jpg  3326.jpg	388.jpg   4440.jpg  498.jpg   91.jpg
# 1466.txt  2013.txt  2757.txt  3326.txt	388.txt   4440.txt  498.txt   91.txt
# 1467.jpg  2014.jpg  2758.jpg  3327.jpg	3890.jpg  4441.jpg  4990.jpg  920.jpg
# 1467.txt  2014.txt  2758.txt  3327.txt	3890.txt  4441.txt  4990.txt  920.txt
# 1468.jpg  2015.jpg  275.jpg   3328.jpg	3891.jpg  4442.jpg  4991.jpg  921.jpg
# 1468.txt  2015.txt  275.txt   3328.txt	3891.txt  4442.txt  4991.txt  921.txt
# 1469.jpg  2016.jpg  2760.jpg  3329.jpg	3892.jpg  4443.jpg  4992.jpg  922.jpg
# 1469.txt  2016.txt  2760.txt  3329.txt	3892.txt  4443.txt  4992.txt  922.txt
# 146.jpg   2017.jpg  2761.jpg  332.jpg	3893.jpg  4444.jpg  4993.jpg  923.jpg
# 146.txt   2017.txt  2761.txt  332.txt	3893.txt  4444.txt  4993.txt  923.txt
# 1470.jpg  2018.jpg  2762.jpg  3330.jpg	3894.jpg  4445.jpg  4994.jpg  924.jpg
# 1470.txt  2018.txt  2762.txt  3330.txt	3894.txt  4445.txt  4994.txt  924.txt
# 1471.jpg  2019.jpg  2763.jpg  3331.jpg	3896.jpg  4446.jpg  4995.jpg  925.jpg
# 1471.txt  2019.txt  2763.txt  3331.txt	3896.txt  4446.txt  4995.txt  925.txt
# 1472.jpg  201.jpg   2764.jpg  3332.jpg	3897.jpg  4447.jpg  4996.jpg  926.jpg
# 1472.txt  201.txt   2764.txt  3332.txt	3897.txt  4447.txt  4996.txt  926.txt
# 1473.jpg  2020.jpg  2765.jpg  3333.jpg	3898.jpg  4448.jpg  4997.jpg  927.jpg
# 1473.txt  2020.txt  2765.txt  3333.txt	3898.txt  4448.txt  4997.txt  927.txt
# 1474.jpg  2021.jpg  2766.jpg  3334.jpg	3899.jpg  4449.jpg  4998.jpg  928.jpg
# 1474.txt  2021.txt  2766.txt  3334.txt	3899.txt  4449.txt  4998.txt  928.txt
# 1475.jpg  2022.jpg  2767.jpg  3335.jpg	389.jpg   444.jpg   4999.jpg  929.jpg
# 1475.txt  2022.txt  2767.txt  3335.txt	389.txt   444.txt   4999.txt  929.txt
# 1476.jpg  2023.jpg  2768.jpg  3336.jpg	38.jpg	  4450.jpg  499.jpg   92.jpg
# 1476.txt  2023.txt  2768.txt  3336.txt	38.txt	  4450.txt  499.txt   92.txt
# 1477.jpg  2024.jpg  2769.jpg  3337.jpg	3900.jpg  4451.jpg  49.jpg    930.jpg
# 1477.txt  2024.txt  2769.txt  3337.txt	3900.txt  4451.txt  49.txt    930.txt
# 1478.jpg  2025.jpg  276.jpg   3338.jpg	3901.jpg  4452.jpg  4.jpg     931.jpg
# 1478.txt  2025.txt  276.txt   3338.txt	3901.txt  4452.txt  4.txt     931.txt
# 1479.jpg  2026.jpg  2770.jpg  3339.jpg	3902.jpg  4453.jpg  5000.jpg  932.jpg
# 1479.txt  2026.txt  2770.txt  3339.txt	3902.txt  4453.txt  5000.txt  932.txt
# 147.jpg   2027.jpg  2771.jpg  333.jpg	3903.jpg  4454.jpg  5001.jpg  933.jpg
# 147.txt   2027.txt  2771.txt  333.txt	3903.txt  4454.txt  5001.txt  933.txt
# 1480.jpg  2028.jpg  2772.jpg  3340.jpg	3904.jpg  4455.jpg  5002.jpg  934.jpg
# 1480.txt  2028.txt  2772.txt  3340.txt	3904.txt  4455.txt  5002.txt  934.txt
# 1481.jpg  2029.jpg  2773.jpg  3341.jpg	3905.jpg  4456.jpg  5003.jpg  935.jpg
# 1481.txt  2029.txt  2773.txt  3341.txt	3905.txt  4456.txt  5003.txt  935.txt
# 1482.jpg  202.jpg   2774.jpg  3342.jpg	3907.jpg  4457.jpg  5004.jpg  936.jpg
# 1482.txt  202.txt   2774.txt  3342.txt	3907.txt  4457.txt  5004.txt  936.txt
# 1483.jpg  2030.jpg  2775.jpg  3343.jpg	3909.jpg  4458.jpg  5005.jpg  937.jpg
# 1483.txt  2030.txt  2775.txt  3343.txt	3909.txt  4458.txt  5005.txt  937.txt
# 1484.jpg  2031.jpg  2776.jpg  3344.jpg	390.jpg   4459.jpg  5006.jpg  938.jpg
# 1484.txt  2031.txt  2776.txt  3344.txt	390.txt   4459.txt  5006.txt  938.txt
# 1485.jpg  2032.jpg  2778.jpg  3345.jpg	3910.jpg  445.jpg   5007.jpg  939.jpg
# 1485.txt  2032.txt  2778.txt  3345.txt	3910.txt  445.txt   5007.txt  939.txt
# 1486.jpg  2033.jpg  277.jpg   3346.jpg	3911.jpg  4460.jpg  5008.jpg  93.jpg
# 1486.txt  2033.txt  277.txt   3346.txt	3911.txt  4460.txt  5008.txt  93.txt
# 1487.jpg  2034.jpg  2780.jpg  3347.jpg	3912.jpg  4461.jpg  5009.jpg  940.jpg
# 1487.txt  2034.txt  2780.txt  3347.txt	3912.txt  4461.txt  5009.txt  940.txt
# 1488.jpg  2035.jpg  2781.jpg  3348.jpg	3913.jpg  4462.jpg  500.jpg   941.jpg
# 1488.txt  2035.txt  2781.txt  3348.txt	3913.txt  4462.txt  500.txt   941.txt
# 1489.jpg  2036.jpg  2782.jpg  3349.jpg	3914.jpg  4463.jpg  5010.jpg  942.jpg
# 1489.txt  2036.txt  2782.txt  3349.txt	3914.txt  4463.txt  5010.txt  942.txt
# 148.jpg   2037.jpg  2783.jpg  334.jpg	3915.jpg  4464.jpg  5011.jpg  943.jpg
# 148.txt   2037.txt  2783.txt  334.txt	3915.txt  4464.txt  5011.txt  943.txt
# 1490.jpg  2038.jpg  2784.jpg  3350.jpg	3916.jpg  4465.jpg  5012.jpg  944.jpg
# 1490.txt  2038.txt  2784.txt  3350.txt	3916.txt  4465.txt  5012.txt  944.txt
# 1491.jpg  2039.jpg  2785.jpg  3351.jpg	3917.jpg  4466.jpg  5013.jpg  945.jpg
# 1491.txt  2039.txt  2785.txt  3351.txt	3917.txt  4466.txt  5013.txt  945.txt
# 1492.jpg  203.jpg   2786.jpg  3352.jpg	3918.jpg  4467.jpg  5014.jpg  946.jpg
# 1492.txt  203.txt   2786.txt  3352.txt	3918.txt  4467.txt  5014.txt  946.txt
# 1493.jpg  2040.jpg  2787.jpg  3353.jpg	3919.jpg  4468.jpg  5015.jpg  947.jpg
# 1493.txt  2040.txt  2787.txt  3353.txt	3919.txt  4468.txt  5015.txt  947.txt
# 1494.jpg  2041.jpg  2788.jpg  3354.jpg	391.jpg   4469.jpg  5016.jpg  948.jpg
# 1494.txt  2041.txt  2788.txt  3354.txt	391.txt   4469.txt  5016.txt  948.txt
# 1495.jpg  2042.jpg  2789.jpg  3355.jpg	3920.jpg  446.jpg   5017.jpg  949.jpg
# 1495.txt  2042.txt  2789.txt  3355.txt	3920.txt  446.txt   5017.txt  949.txt
# 1496.jpg  2043.jpg  278.jpg   3356.jpg	3921.jpg  4470.jpg  5018.jpg  94.jpg
# 1496.txt  2043.txt  278.txt   3356.txt	3921.txt  4470.txt  5018.txt  94.txt
# 1497.jpg  2044.jpg  2790.jpg  3357.jpg	3922.jpg  4471.jpg  5019.jpg  950.jpg
# 1497.txt  2044.txt  2790.txt  3357.txt	3922.txt  4471.txt  5019.txt  950.txt
# 1498.jpg  2045.jpg  2791.jpg  3358.jpg	3923.jpg  4472.jpg  501.jpg   951.jpg
# 1498.txt  2045.txt  2791.txt  3358.txt	3923.txt  4472.txt  501.txt   951.txt
# 1499.jpg  2046.jpg  2792.jpg  3359.jpg	3924.jpg  4473.jpg  5020.jpg  952.jpg
# 1499.txt  2046.txt  2792.txt  3359.txt	3924.txt  4473.txt  5020.txt  952.txt
# 149.jpg   2047.jpg  2793.jpg  335.jpg	3925.jpg  4474.jpg  5021.jpg  953.jpg
# 149.txt   2047.txt  2793.txt  335.txt	3925.txt  4474.txt  5021.txt  953.txt
# 14.jpg	  2048.jpg  2794.jpg  3360.jpg	3926.jpg  4475.jpg  5022.jpg  954.jpg
# 14.txt	  2048.txt  2794.txt  3360.txt	3926.txt  4475.txt  5022.txt  954.txt
# 1500.jpg  2049.jpg  2795.jpg  3361.jpg	3927.jpg  4476.jpg  5023.jpg  955.jpg
# 1500.txt  2049.txt  2795.txt  3361.txt	3927.txt  4476.txt  5023.txt  955.txt
# 1501.jpg  204.jpg   2796.jpg  3362.jpg	3928.jpg  4477.jpg  5024.jpg  956.jpg
# 1501.txt  204.txt   2796.txt  3362.txt	3928.txt  4477.txt  5024.txt  956.txt
# 1502.jpg  2050.jpg  2797.jpg  3363.jpg	3929.jpg  4478.jpg  5025.jpg  957.jpg
# 1502.txt  2050.txt  2797.txt  3363.txt	3929.txt  4478.txt  5025.txt  957.txt
# 1503.jpg  2051.jpg  2798.jpg  3364.jpg	392.jpg   4479.jpg  5026.jpg  958.jpg
# 1503.txt  2051.txt  2798.txt  3364.txt	392.txt   4479.txt  5026.txt  958.txt
# 1504.jpg  2052.jpg  2799.jpg  3365.jpg	3930.jpg  447.jpg   5027.jpg  959.jpg
# 1504.txt  2052.txt  2799.txt  3365.txt	3930.txt  447.txt   5027.txt  959.txt
# 1505.jpg  2053.jpg  279.jpg   3366.jpg	3931.jpg  4480.jpg  5028.jpg  95.jpg
# 1505.txt  2053.txt  279.txt   3366.txt	3931.txt  4480.txt  5028.txt  95.txt
# 1506.jpg  2054.jpg  27.jpg    3367.jpg	3932.jpg  4481.jpg  5029.jpg  960.jpg
# 1506.txt  2054.txt  27.txt    3367.txt	3932.txt  4481.txt  5029.txt  960.txt
# 1507.jpg  2055.jpg  2800.jpg  3368.jpg	3933.jpg  4482.jpg  502.jpg   961.jpg
# 1507.txt  2055.txt  2800.txt  3368.txt	3933.txt  4482.txt  502.txt   961.txt
# 1508.jpg  2056.jpg  2801.jpg  3369.jpg	3934.jpg  4483.jpg  5030.jpg  962.jpg
# 1508.txt  2056.txt  2801.txt  3369.txt	3934.txt  4483.txt  5030.txt  962.txt
# 1509.jpg  2057.jpg  2803.jpg  336.jpg	3935.jpg  4484.jpg  5031.jpg  963.jpg
# 1509.txt  2057.txt  2803.txt  336.txt	3935.txt  4484.txt  5031.txt  963.txt
# 150.jpg   2058.jpg  2804.jpg  3370.jpg	3936.jpg  4485.jpg  5032.jpg  964.jpg
# 150.txt   2058.txt  2804.txt  3370.txt	3936.txt  4485.txt  5032.txt  964.txt
# 1510.jpg  2059.jpg  2806.jpg  3371.jpg	3937.jpg  4486.jpg  5033.jpg  965.jpg
# 1510.txt  2059.txt  2806.txt  3371.txt	3937.txt  4486.txt  5033.txt  965.txt
# 1511.jpg  205.jpg   2807.jpg  3372.jpg	3938.jpg  4487.jpg  5034.jpg  966.jpg
# 1511.txt  205.txt   2807.txt  3372.txt	3938.txt  4487.txt  5034.txt  966.txt
# 1512.jpg  2060.jpg  2808.jpg  3373.jpg	3939.jpg  4488.jpg  5035.jpg  967.jpg
# 1512.txt  2060.txt  2808.txt  3373.txt	3939.txt  4488.txt  5035.txt  967.txt
# 1513.jpg  2061.jpg  2809.jpg  3374.jpg	393.jpg   4489.jpg  5036.jpg  968.jpg
# 1513.txt  2061.txt  2809.txt  3374.txt	393.txt   4489.txt  5036.txt  968.txt
# 1514.jpg  2062.jpg  280.jpg   3375.jpg	3940.jpg  448.jpg   5037.jpg  969.jpg
# 1514.txt  2062.txt  280.txt   3375.txt	3940.txt  448.txt   5037.txt  969.txt
# 1515.jpg  2063.jpg  2810.jpg  3376.jpg	3941.jpg  4490.jpg  5038.jpg  96.jpg
# 1515.txt  2063.txt  2810.txt  3376.txt	3941.txt  4490.txt  5038.txt  96.txt
# 1516.jpg  2064.jpg  2811.jpg  3377.jpg	3942.jpg  4491.jpg  5039.jpg  970.jpg
# 1516.txt  2064.txt  2811.txt  3377.txt	3942.txt  4491.txt  5039.txt  970.txt
# 1517.jpg  2065.jpg  2812.jpg  3378.jpg	3943.jpg  4492.jpg  503.jpg   971.jpg
# 1517.txt  2065.txt  2812.txt  3378.txt	3943.txt  4492.txt  503.txt   971.txt
# 1518.jpg  2066.jpg  2813.jpg  3379.jpg	3944.jpg  4493.jpg  5040.jpg  972.jpg
# 1518.txt  2066.txt  2813.txt  3379.txt	3944.txt  4493.txt  5040.txt  972.txt
# 1519.jpg  2067.jpg  2814.jpg  337.jpg	3945.jpg  4494.jpg  5041.jpg  973.jpg
# 1519.txt  2067.txt  2814.txt  337.txt	3945.txt  4494.txt  5041.txt  973.txt
# 151.jpg   2068.jpg  2815.jpg  3380.jpg	3946.jpg  4495.jpg  5042.jpg  974.jpg
# 151.txt   2068.txt  2815.txt  3380.txt	3946.txt  4495.txt  5042.txt  974.txt
# 1520.jpg  2069.jpg  2816.jpg  3381.jpg	3947.jpg  4496.jpg  5043.jpg  975.jpg
# 1520.txt  2069.txt  2816.txt  3381.txt	3947.txt  4496.txt  5043.txt  975.txt
# 1521.jpg  206.jpg   2817.jpg  3382.jpg	3948.jpg  4497.jpg  5044.jpg  976.jpg
# 1521.txt  206.txt   2817.txt  3382.txt	3948.txt  4497.txt  5044.txt  976.txt
# 1522.jpg  2070.jpg  2818.jpg  3383.jpg	3949.jpg  4498.jpg  5045.jpg  977.jpg
# 1522.txt  2070.txt  2818.txt  3383.txt	3949.txt  4498.txt  5045.txt  977.txt
# 1523.jpg  2071.jpg  2819.jpg  3384.jpg	394.jpg   4499.jpg  5046.jpg  978.jpg
# 1523.txt  2071.txt  2819.txt  3384.txt	394.txt   4499.txt  5046.txt  978.txt
# 1524.jpg  2072.jpg  281.jpg   3385.jpg	3950.jpg  449.jpg   5047.jpg  979.jpg
# 1524.txt  2072.txt  281.txt   3385.txt	3950.txt  449.txt   5047.txt  979.txt
# 1525.jpg  2073.jpg  2820.jpg  3386.jpg	3951.jpg  44.jpg    5048.jpg  97.jpg
# 1525.txt  2073.txt  2820.txt  3386.txt	3951.txt  44.txt    5048.txt  97.txt
# 1526.jpg  2074.jpg  2821.jpg  3387.jpg	3952.jpg  4500.jpg  5049.jpg  980.jpg
# 1526.txt  2074.txt  2821.txt  3387.txt	3952.txt  4500.txt  5049.txt  980.txt
# 1527.jpg  2075.jpg  2822.jpg  3388.jpg	3953.jpg  4501.jpg  504.jpg   981.jpg
# 1527.txt  2075.txt  2822.txt  3388.txt	3953.txt  4501.txt  504.txt   981.txt
# 1528.jpg  2076.jpg  2823.jpg  3389.jpg	3954.jpg  4502.jpg  5050.jpg  982.jpg
# 1528.txt  2076.txt  2823.txt  3389.txt	3954.txt  4502.txt  5050.txt  982.txt
# 1529.jpg  2077.jpg  2824.jpg  338.jpg	3955.jpg  4503.jpg  5051.jpg  983.jpg
# 1529.txt  2077.txt  2824.txt  338.txt	3955.txt  4503.txt  5051.txt  983.txt
# 152.jpg   2078.jpg  2826.jpg  3390.jpg	3956.jpg  4504.jpg  5052.jpg  984.jpg
# 152.txt   2078.txt  2826.txt  3390.txt	3956.txt  4504.txt  5052.txt  984.txt
# 1530.jpg  2079.jpg  2827.jpg  3391.jpg	3957.jpg  4505.jpg  5053.jpg  985.jpg
# 1530.txt  2079.txt  2827.txt  3391.txt	3957.txt  4505.txt  5053.txt  985.txt
# 1531.jpg  207.jpg   2828.jpg  3392.jpg	3958.jpg  4506.jpg  5054.jpg  986.jpg
# 1531.txt  207.txt   2828.txt  3392.txt	3958.txt  4506.txt  5054.txt  986.txt
# 1532.jpg  2080.jpg  2829.jpg  3393.jpg	3959.jpg  4507.jpg  5055.jpg  987.jpg
# 1532.txt  2080.txt  2829.txt  3393.txt	3959.txt  4507.txt  5055.txt  987.txt
# 1533.jpg  2081.jpg  282.jpg   3394.jpg	395.jpg   4508.jpg  5056.jpg  988.jpg
# 1533.txt  2081.txt  282.txt   3394.txt	395.txt   4508.txt  5056.txt  988.txt
# 1534.jpg  2082.jpg  2830.jpg  3395.jpg	3961.jpg  4509.jpg  5057.jpg  989.jpg
# 1534.txt  2082.txt  2830.txt  3395.txt	3961.txt  4509.txt  5057.txt  989.txt
# 1535.jpg  2083.jpg  2832.jpg  3396.jpg	3962.jpg  450.jpg   5058.jpg  98.jpg
# 1535.txt  2083.txt  2832.txt  3396.txt	3962.txt  450.txt   5058.txt  98.txt
# 1536.jpg  2084.jpg  2833.jpg  3397.jpg	3963.jpg  4510.jpg  5059.jpg  990.jpg
# 1536.txt  2084.txt  2833.txt  3397.txt	3963.txt  4510.txt  5059.txt  990.txt
# 1537.jpg  2085.jpg  2836.jpg  3398.jpg	3964.jpg  4511.jpg  505.jpg   991.jpg
# 1537.txt  2085.txt  2836.txt  3398.txt	3964.txt  4511.txt  505.txt   991.txt
# 1538.jpg  2086.jpg  2837.jpg  3399.jpg	3965.jpg  4512.jpg  5060.jpg  992.jpg
# 1538.txt  2086.txt  2837.txt  3399.txt	3965.txt  4512.txt  5060.txt  992.txt
# 1539.jpg  2087.jpg  2838.jpg  339.jpg	3966.jpg  4513.jpg  5061.jpg  993.jpg
# 1539.txt  2087.txt  2838.txt  339.txt	3966.txt  4513.txt  5061.txt  993.txt
# 153.jpg   2088.jpg  2839.jpg  33.jpg	3967.jpg  4514.jpg  5062.jpg  994.jpg
# 153.txt   2088.txt  2839.txt  33.txt	3967.txt  4514.txt  5062.txt  994.txt
# 1540.jpg  2089.jpg  283.jpg   3400.jpg	3968.jpg  4515.jpg  5063.jpg  995.jpg
# 1540.txt  2089.txt  283.txt   3400.txt	3968.txt  4515.txt  5063.txt  995.txt
# 1541.jpg  208.jpg   2840.jpg  3401.jpg	3969.jpg  4516.jpg  5064.jpg  996.jpg
# 1541.txt  208.txt   2840.txt  3401.txt	3969.txt  4516.txt  5064.txt  996.txt
# 1542.jpg  2090.jpg  2841.jpg  3402.jpg	396.jpg   4517.jpg  5065.jpg  997.jpg
# 1542.txt  2090.txt  2841.txt  3402.txt	396.txt   4517.txt  5065.txt  997.txt
# 1543.jpg  2091.jpg  2842.jpg  3403.jpg	3970.jpg  4518.jpg  5066.jpg  998.jpg
# 1543.txt  2091.txt  2842.txt  3403.txt	3970.txt  4518.txt  5066.txt  998.txt
# 1544.jpg  2092.jpg  2843.jpg  3404.jpg	3971.jpg  4519.jpg  5067.jpg  999.jpg
# 1544.txt  2092.txt  2843.txt  3404.txt	3971.txt  4519.txt  5067.txt  999.txt
# 1545.jpg  2093.jpg  2844.jpg  3405.jpg	3972.jpg  451.jpg   5068.jpg  99.jpg
# 1545.txt  2093.txt  2844.txt  3405.txt	3972.txt  451.txt   5068.txt  99.txt
# 1546.jpg  2094.jpg  2845.jpg  3406.jpg	3973.jpg  4520.jpg  5069.jpg  9.jpg
# 1546.txt  2094.txt  2845.txt  3406.txt	3973.txt  4520.txt  5069.txt  9.txt
# 1547.jpg  2095.jpg  2846.jpg  3407.jpg	3974.jpg  4521.jpg  506.jpg
# 1547.txt  2095.txt  2846.txt  3407.txt	3974.txt  4521.txt  506.txt
# 1548.jpg  2096.jpg  2847.jpg  3408.jpg	3975.jpg  4522.jpg  5070.jpg
# 1548.txt  2096.txt  2847.txt  3408.txt	3975.txt  4522.txt  5070.txt
# 1549.jpg  2097.jpg  2848.jpg  3409.jpg	3976.jpg  4523.jpg  5071.jpg
# 1549.txt  2097.txt  2848.txt  3409.txt	3976.txt  4523.txt  5071.txt

# %%
import os
from pathlib import Path
import pandas as pd

ROOT_DIR   = "/content/mvsa_raw/MVSA_Single"
DATA_DIR   = os.path.join(ROOT_DIR, "data")
LABEL_FILE = os.path.join(ROOT_DIR, "labelResultAll.txt")

print("ROOT_DIR :", ROOT_DIR)
print("DATA_DIR :", DATA_DIR)
print("LABEL_FILE:", LABEL_FILE)

# 1) Read labelResultAll.txt
# First column: ID
# Second column header: "text,image"
labels_raw = pd.read_csv(LABEL_FILE, sep=r"\s+", engine="python")
print(labels_raw.head())
print("Columns:", labels_raw.columns)

# 2) Split "text,image" into two sentiment columns
sent_col = labels_raw.columns[1]  # should be "text,image"
labels_raw[["text_sent", "image_sent"]] = labels_raw[sent_col].str.split(",", expand=True)

# 3) Use text sentiment as label
labels = labels_raw[["ID", "text_sent"]].copy()
labels["ID"] = labels["ID"].astype(int)
labels["text_sent"] = labels["text_sent"].str.lower().str.strip()

sent_to_id = {"negative": 0, "neutral": 1, "positive": 2}
labels["label"] = labels["text_sent"].map(sent_to_id)

print("Sentiment mapping:", sent_to_id)
print(labels.head())
# Out:
# ROOT_DIR : /content/mvsa_raw/MVSA_Single
# DATA_DIR : /content/mvsa_raw/MVSA_Single/data
# LABEL_FILE: /content/mvsa_raw/MVSA_Single/labelResultAll.txt
#    ID         text,image
# 0   1   neutral,positive
# 1   2   neutral,positive
# 2   3   neutral,positive
# 3   4  positive,positive
# 4   5  positive,positive
# Columns: Index(['ID', 'text,image'], dtype='object')
# Sentiment mapping: {'negative': 0, 'neutral': 1, 'positive': 2}
#    ID text_sent  label
# 0   1   neutral      1
# 1   2   neutral      1
# 2   3   neutral      1
# 3   4  positive      2
# 4   5  positive      2

# %%
rows = []

for _, row in labels.iterrows():
    id_int = row["ID"]
    id_str = str(id_int)

    img_path = os.path.join(DATA_DIR, f"{id_str}.jpg")
    txt_path = os.path.join(DATA_DIR, f"{id_str}.txt")

    # ensure both files exist
    if not (os.path.exists(img_path) and os.path.exists(txt_path)):
        continue

    # read text
    with open(txt_path, "r", encoding="utf-8", errors="ignore") as f:
        text = f.read().strip()

    if not text:
        continue

    rows.append({
        "id": id_int,
        "text": text,
        "image_path": img_path,
        "label": row["label"],
    })

df = pd.DataFrame(rows)
print(df.head())
print("Total usable samples:", len(df))

# Optional: subsample for quicker training
N_SAMPLES = 4000  # adjust as you like
if len(df) > N_SAMPLES:
    df = df.sample(N_SAMPLES, random_state=42).reset_index(drop=True)

print("Using samples:", len(df))
df["label"].value_counts()
# Out:
#    id                                               text  \
# 0   1       How I feel today #legday #jelly #aching #gym
# 1   2  grattis min griskulting!!!???? va bara tvungen...
# 2   3  RT @polynminion: The moment I found my favouri...
# 3   4  #escort We have a young and energetic team and...
# 4   5  RT @chrisashaffer: Went to SSC today to be a "...
#
#                                  image_path  label
# 0  /content/mvsa_raw/MVSA_Single/data/1.jpg      1
# 1  /content/mvsa_raw/MVSA_Single/data/2.jpg      1
# 2  /content/mvsa_raw/MVSA_Single/data/3.jpg      1
# 3  /content/mvsa_raw/MVSA_Single/data/4.jpg      2
# 4  /content/mvsa_raw/MVSA_Single/data/5.jpg      2
# Total usable samples: 4869
# Using samples: 4000
# label
# 1    1569
# 2    1427
# 0    1004
# Name: count, dtype: int64

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import torch

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
MAX_LEN = 64

# Image transforms
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.1, contrast=0.1,
                           saturation=0.1, hue=0.02),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225]),
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225]),
])

class MVSASingleDataset(Dataset):
    def __init__(self, df, transform):
        self.df = df.reset_index(drop=True)
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        # text → tokens
        text = str(row["text"])
        enc = tokenizer(
            text,
            padding="max_length",
            truncation=True,
            max_length=MAX_LEN,
            return_tensors="pt"
        )

        # image
        image = Image.open(row["image_path"]).convert("RGB")
        image = self.transform(image)

        label = torch.tensor(row["label"], dtype=torch.long)

        return {
            "input_ids": enc["input_ids"].squeeze(0),
            "attention_mask": enc["attention_mask"].squeeze(0),
            "image": image,
            "label": label
        }

# Stratified split
train_df, val_df = train_test_split(
    df,
    test_size=0.2,
    stratify=df["label"],
    random_state=42
)

train_dataset = MVSASingleDataset(train_df, transform=train_transform)
val_dataset   = MVSASingleDataset(val_df,   transform=val_transform)

BATCH_SIZE = 16

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False)

len(train_loader), len(val_loader)
# Out:
# (200, 50)

# %%
import torch.nn as nn
from transformers import AutoModel
from torchvision import models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

class MultimodalSentimentNet(nn.Module):
    def __init__(self, num_classes=3):
        super().__init__()

        # Text encoder
        self.text_encoder = AutoModel.from_pretrained("bert-base-uncased")
        text_dim = self.text_encoder.config.hidden_size  # 768

        # Image encoder
        resnet = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
        img_dim = resnet.fc.in_features                  # 512
        resnet.fc = nn.Identity()
        self.image_encoder = resnet

        # Fusion classifier
        fusion_dim = text_dim + img_dim  # 768 + 512
        self.classifier = nn.Sequential(
            nn.Linear(fusion_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(256, num_classes)
        )

    def forward(self, input_ids, attention_mask, images):
        # Text branch
        text_out = self.text_encoder(
            input_ids=input_ids,
            attention_mask=attention_mask
        )
        text_emb = text_out.last_hidden_state[:, 0, :]  # CLS token

        # Image branch
        img_emb = self.image_encoder(images)

        # Fuse
        fused = torch.cat([text_emb, img_emb], dim=1)
        logits = self.classifier(fused)
        return logits

NUM_CLASSES = 3  # negative / neutral / positive
model = MultimodalSentimentNet(num_classes=NUM_CLASSES).to(device)
# Out:
# Device: cuda
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:04<00:00, 10.5MB/s]

# %%
import torch.nn as nn
from torch.optim import AdamW

# Class weights (handle imbalance)
class_counts = train_df["label"].value_counts().sort_index().values.astype(np.float32)
inv = 1.0 / class_counts
weights = inv / inv.sum() * len(class_counts)

class_weights = torch.tensor(weights, dtype=torch.float32).to(device)
print("Class counts :", class_counts)
print("Class weights:", class_weights)

criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = AdamW(model.parameters(), lr=1e-4, weight_decay=1e-2)
# Out:
# Class counts : [ 803. 1255. 1142.]
# Class weights: tensor([1.2804, 0.8193, 0.9003], device='cuda:0')

# %%
from torch.nn.functional import cross_entropy

def run_epoch(loader, train=True):
    if train:
        model.train()
    else:
        model.eval()

    total_loss = 0.0
    correct = 0
    total = 0

    for batch in loader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        images = batch["image"].to(device)
        labels = batch["label"].to(device)

        if train:
            optimizer.zero_grad()

        with torch.set_grad_enabled(train):
            logits = model(input_ids, attention_mask, images)
            loss = criterion(logits, labels)

            if train:
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()

        preds = torch.argmax(logits, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
        total_loss += loss.item()

    avg_loss = total_loss / len(loader)
    acc = correct / total
    return avg_loss, acc


EPOCHS = 15
best_val_acc = 0.0
patience = 3
patience_counter = 0
best_path = "/content/mvsa_multimodal_best.pt"

for epoch in range(1, EPOCHS + 1):
    train_loss, train_acc = run_epoch(train_loader, train=True)
    val_loss, val_acc = run_epoch(val_loader, train=False)

    print(f"Epoch {epoch:02d}: "
          f"train_loss={train_loss:.4f}, train_acc={train_acc:.3f}, "
          f"val_loss={val_loss:.4f}, val_acc={val_acc:.3f}")

    # Early stopping on val_acc
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        patience_counter = 0
        torch.save(model.state_dict(), best_path)
        print(f"  🔸 New best model saved (val_acc={best_val_acc:.3f})")
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("  🔻 Early stopping triggered.")
            break

print("Best validation accuracy:", best_val_acc)
# Out:
# Epoch 01: train_loss=0.9028, train_acc=0.583, val_loss=0.7931, val_acc=0.679
#   🔸 New best model saved (val_acc=0.679)
# Epoch 02: train_loss=0.6792, train_acc=0.747, val_loss=0.8670, val_acc=0.693
#   🔸 New best model saved (val_acc=0.693)
# Epoch 03: train_loss=0.4954, train_acc=0.841, val_loss=1.0891, val_acc=0.698
#   🔸 New best model saved (val_acc=0.698)
# Epoch 04: train_loss=0.3749, train_acc=0.891, val_loss=1.0736, val_acc=0.703
#   🔸 New best model saved (val_acc=0.703)
# Epoch 05: train_loss=0.3116, train_acc=0.913, val_loss=1.3244, val_acc=0.693
# Epoch 06: train_loss=0.2940, train_acc=0.922, val_loss=1.4329, val_acc=0.682
# Epoch 07: train_loss=0.2115, train_acc=0.947, val_loss=1.8094, val_acc=0.686
#   🔻 Early stopping triggered.
# Best validation accuracy: 0.7025

# %%
model.load_state_dict(torch.load(best_path, map_location=device))
model.eval()

FINAL_SAVE = "/content/mvsa_multimodal_sentiment.pt"
torch.save(model.state_dict(), FINAL_SAVE)
print("Final best model saved at:", FINAL_SAVE)
# Out:
# Final best model saved at: /content/mvsa_multimodal_sentiment.pt
